# %% [markdown]
# # Streaming multispeaker ASR and diarization tutorial

# %%
"""
You can run either this notebook locally (if you have all the dependencies and a GPU) or on Google Colab.

Instructions for setting up Colab are as follows:
1. Open a new Python 3 notebook.
2. Import this notebook from GitHub (File -> Upload Notebook -> "GITHUB" tab -> copy/paste GitHub URL)
3. Connect to an instance with a GPU (Runtime -> Change runtime type -> select "GPU" for hardware accelerator)
4. Run this cell to set up dependencies.
"""
# If you're using Google Colab and not running locally, run this cell.

if False: 
    ## Install dependencies
    # !pip install wget
    # !apt-get install sox libsndfile1 ffmpeg
    # !pip install text-unidecode

    # ## Install NeMo
    BRANCH = 'main'
    # !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[asr]

    ## Install TorchAudio
    # !pip install torchaudio -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# UsageError: Line magic function `%%script` not found.

# %%
import os
import sys
print(sys.path)
sys.path.insert(0,f'/home/taejinp/projects/online_diar/NeMo/')
import nemo
print("Nemo PATH:", nemo.__path__)
BRANCH = 'streaming_mulspk_asr'
# Out:
# ['/home/taejinp/projects/online_diar/NeMo/tutorials/speaker_tasks', '/home/taejinp/projects/online_diar/NeMo/tutorials/speaker_tasks', '/usr/local/lib/python3.6/dist-packages/torchtext_mod', '/usr/local/lib/python3.6/dist-packages/torchtext_edit', '/usr/local/lib/python3.6/dist-packages/torchtext_edit/data', '/home/taejinp/anaconda3/envs/e2py310/lib/python310.zip', '/home/taejinp/anaconda3/envs/e2py310/lib/python3.10', '/home/taejinp/anaconda3/envs/e2py310/lib/python3.10/lib-dynload', '', '/home/taejinp/anaconda3/envs/e2py310/lib/python3.10/site-packages']
# Nemo PATH: ['/home/taejinp/projects/online_diar/NeMo/nemo']

# %% [markdown]
# # Online Speaker Diarization
#
# Speaker diarization is the process of determining "who spoke when" in a given audio clip. Depending on the method of processing, speaker diarization can be categorized into two types:
#
# - **Offline Speaker Diarization**: This method assumes access to the entire audio clip. The transcription, indicating which speaker spoke at which time, is provided after processing the audio from start to end.
#
# - **Online Speaker Diarization**: In this approach, the system only gradually gains access to short segments of the audio, typically a few seconds long. The transcription is generated and displayed in real-time as the segmented audio is being processed.

# %%
import sys
import socket
if socket.gethostname() == "aiapps-06052021":
    sys.path.insert(0,'/home/taejinp/projects/streaming_mulspk_asr/NeMo')
else:
    sys.path.insert(0,'/your/path/to/NeMo/')
    
import nemo
print("Using Nemo PATH:", nemo.__path__[0])

# !pip install gradio==2.9.0
# Out:
# Using Nemo PATH: /home/taejinp/projects/online_diar/NeMo/nemo

# %%
# Introduction to Online Speaker Diarization
"""
As covered in Speaker diarization inference tutorial, speaker diarization is the task of segmenting audio recordings by speaker labels and answers the question "Who Speaks When?".

While offline speaker diarization has access to the entire audio file and return the speaker labels all at once, online speaker diarization is a streaming task that processes audio in small chunks. 
Since we only have access to a small chunk of audio at a time, the online speaker diarization system needs to maintain a memory buffer to store the history of the speakers in the past. At the sametime, the system needs to be able to detect new speakers that are not in the memory buffer.

This tutorial will cover the followings:

- How to run online speaker diarization with NeMo
- How online speaker clustering and memory buffer works together
"""
# Out:
# '\nAs covered in Speaker diarization inference tutorial, speaker diarization is the task of segmenting audio recordings by speaker labels and answers the question "Who Speaks When?".\n\nWhile offline speaker diarization has access to the entire audio file and return the speaker labels all at once, online speaker diarization is a streaming task that processes audio in small chunks. \nSince we only have access to a small chunk of audio at a time, the online speaker diarization system needs to maintain a memory buffer to store the history of the speakers in the past. At the sametime, the system needs to be able to detect new speakers that are not in the memory buffer.\n\nThis tutorial will cover the followings:\n\n- How to run online speaker diarization with NeMo\n- How online speaker clustering and memory buffer works together\n'

# %%
from nemo.collections.asr.parts.utils.speaker_utils import audio_rttm_map
from nemo.core.config import hydra_runner
import gradio as gr
from scipy.io import wavfile
import numpy as np
import hydra
import os
import torch
from nemo.collections.asr.models import OnlineClusteringDiarizer
# from nemo.collections.asr.parts.utils.diarization_utils import ASR_DIAR_ONLINE
from nemo.collections.asr.parts.utils.diarization_utils import OnlineDiarWithASR

# %% [markdown]
# Read yaml file for online diarization. You have to specifty the following items:
#
# - input manifest file (If  simulation)
# - VAD model path
# - Speaker embedding extractor model path
# - Diarization Decoder model path (Coming soon)
# - Punctuation model path (automatically download from NGC)
# - Language model path (Coming soon)
#
# Download nemo models and specify the path to config struct.

# %%
import omegaconf

YAML_FILE="/home/taejinp/projects/streaming_mulspk_asr/NeMo/examples/speaker_tasks/diarization/conf/inference/online_diar_infer_general.yaml"
cfg = omegaconf.OmegaConf.load(YAML_FILE)
import socket

cfg.diarizer.out_dir = "./streaming_diar_output"

os.makedirs(cfg.diarizer.out_dir, exist_ok=True)
cfg.diarizer.asr.parameters.colored_text = False
print(f"socket.gethostname() {socket.gethostname()}")
if socket.gethostname() == "aiapps-06052021":
    # cfg.diarizer.manifest_filepath = "/home/taejinp/projects/data/diar_manifest_input/ch109.json"
    cfg.diarizer.manifest_filepath = "/home/taejinp/projects/data/diar_manifest_input/online_diar_demo_01.json"
    cfg.diarizer.vad.model_path = "/home/taejinp/gdrive/model/VAD_models/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo"
    cfg.diarizer.speaker_embeddings.model_path = "/home/taejinp/Downloads/titanet_target_fixed/titanet-l.nemo"
    cfg.diarizer.asr.model_path = "/home/taejinp/gdrive/model/ASR_models/Conformer-CTC-BPE_large_Riva_ASR_set_3.0_ep60.nemo"
    cfg.diarizer.asr.parameters.punctuation_model_path = "punctuation_en_distilbert"
else:
    # Please download the following models and run the code. 

    # Download CH109 dataset at: https://drive.google.com/drive/folders/1ksq10H-NZbKRfMjEP_WWyBF_G0iAJt6b?usp=sharing
    cfg.diarizer.manifest_filepath = "/your/path/to/ch109.json"

    # Download streaming VAD model at: https://drive.google.com/file/d/1ab42CaYeTkuJSMsMsMLbSS9m5e1isJzx/view?usp=sharing
    cfg.diarizer.vad.model_path = "/your/path/to/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo"

    # Download titanet-m model at: https://drive.google.com/file/d/1xAgjm0udKogPrlQF6cdHLobEKHLY9azA/view?usp=sharing
    cfg.diarizer.speaker_embeddings.model_path = "/your/path/to/titanet-m.nemo"

    # Download Conformer-CTC ASR model at: https://drive.google.com/file/d/1Xg075IbiwL0szI4_a8gYmCPaG1UsgR6E/view?usp=sharing
    cfg.diarizer.asr.model_path = "/your/path/to/Conformer-CTC-BPE_large_Riva_ASR_set_3.0_ep60.nemo"

    cfg.diarizer.asr.parameters.punctuation_model_path = "punctuation_en_distilbert"
# Out:
# socket.gethostname() aiapps-06052021

# %% [markdown]
# Initialize ASR_DIAR_ONLINE and OnlineDiarizer Class.

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:400px; 
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
from nemo.collections.asr.models import OnlineClusteringDiarizer
import os

params = {}
params['use_cuda'] = True
AUDIO_RTTM_MAP = audio_rttm_map(cfg.diarizer.manifest_filepath)

diar = OnlineClusteringDiarizer(cfg)
from nemo.collections.asr.parts.utils.diarization_utils import OnlineDiarWithASR, write_txt

cfg.diarizer.simulation_uniq_id='citadel_ken'
cfg.diarizer.out_dir = '/home/taejinp/projects/run_time/streaming_diar_output_univ'
cfg.diarizer.asr.parameters.streaming_simulation=True
cfg.diarizer.asr.parameters.enforce_real_time=True 
cfg.diarizer.asr.parameters.colored_text=False
 
fn = os.path.join(cfg.diarizer.out_dir, "print_script.sh")
# os.remove(fn) if os.path.exists(fn) else None

diar.uniq_id = cfg.diarizer.simulation_uniq_id 
diar.single_audio_file_path = AUDIO_RTTM_MAP[diar.uniq_id]['audio_filepath']
diar.rttm_file_path = AUDIO_RTTM_MAP[diar.uniq_id]['rttm_filepath']
# diar.rttm_file_path = None # DER calculation slows down online diarization speed
diar._init_segment_variables()


online_diar_asr = OnlineDiarWithASR(cfg=cfg)
diar = online_diar_asr.diar

diar.device = online_diar_asr.device
online_diar_asr.reset()

# cfg.diarizer.asr.parameters.streaming_simulation=True
cfg.diarizer.asr.parameters.streaming_simulation=False

if not cfg.diarizer.asr.parameters.streaming_simulation:
    cfg.diarizer.asr.parameters.enforce_real_time=False
# Out:
# [NeMo I 2023-10-26 17:26:06 speaker_utils:93] Number of files to diarize: 4
# [NeMo W 2023-10-26 17:26:07 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/ami_train_0.63.json,/manifests/freesound_background_train.json,/manifests/freesound_laughter_train.json,/manifests/fisher_2004_background.json,/manifests/fisher_2004_speech_sampled.json,/manifests/google_train_manifest.json,/manifests/icsi_all_0.63.json,/manifests/musan_freesound_train.json,/manifests/musan_music_train.json,/manifests/musan_soundbible_train.json,/manifests/mandarin_train_sample.json,/manifests/german_train_sample.json,/manifests/spanish_train_sample.json,/manifests/french_train_sample.json,/manifests/russian_train_sample.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       shift:
#         prob: 0.5
#         min_shift_ms: -10.0
#         max_shift_ms: 10.0
#       white_noise:
#         prob: 0.5
#         min_level: -90
#         max_level: -46
#         norm: true
#       noise:
#         prob: 0.5
#         manifest_path: /manifests/noise_0_1_musan_fs.json
#         min_snr_db: 0
#         max_snr_db: 30
#         max_gain_db: 300.0
#         norm: true
#       gain:
#         prob: 0.5
#         min_gain_dbfs: -10.0
#         max_gain_dbfs: 10.0
#         norm: true
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:07 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/ami_dev_0.63.json,/manifests/freesound_background_dev.json,/manifests/freesound_laughter_dev.json,/manifests/ch120_moved_0.63.json,/manifests/fisher_2005_500_speech_sampled.json,/manifests/google_dev_manifest.json,/manifests/musan_music_dev.json,/manifests/mandarin_dev.json,/manifests/german_dev.json,/manifests/spanish_dev.json,/manifests/french_dev.json,/manifests/russian_dev.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: false
#     val_loss_idx: 0
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:07 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 128
#     shuffle: false
#     test_loss_idx: 0
# [NeMo I 2023-10-26 17:26:07 features:289] PADDING: 16
# [NeMo I 2023-10-26 17:26:08 save_restore_connector:249] Model EncDecClassificationModel was successfully restored from /home/taejinp/gdrive/model/VAD_models/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo.
# [NeMo I 2023-10-26 17:26:08 clustering_diarizer:120] VAD model loaded locally from /home/taejinp/gdrive/model/VAD_models/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo
# [NeMo W 2023-10-26 17:26:08 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:08 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2023-10-26 17:26:08 features:289] PADDING: 16
# [NeMo I 2023-10-26 17:26:08 save_restore_connector:249] Model EncDecSpeakerLabelModel was successfully restored from /home/taejinp/Downloads/titanet_target_fixed/titanet-l.nemo.
# [NeMo I 2023-10-26 17:26:08 clustering_diarizer:145] Speaker Model restored locally from /home/taejinp/Downloads/titanet_target_fixed/titanet-l.nemo
# [NeMo I 2023-10-26 17:26:08 speaker_utils:93] Number of files to diarize: 4
# [NeMo I 2023-10-26 17:26:08 speaker_utils:93] Number of files to diarize: 4
# [NeMo W 2023-10-26 17:26:08 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/ami_train_0.63.json,/manifests/freesound_background_train.json,/manifests/freesound_laughter_train.json,/manifests/fisher_2004_background.json,/manifests/fisher_2004_speech_sampled.json,/manifests/google_train_manifest.json,/manifests/icsi_all_0.63.json,/manifests/musan_freesound_train.json,/manifests/musan_music_train.json,/manifests/musan_soundbible_train.json,/manifests/mandarin_train_sample.json,/manifests/german_train_sample.json,/manifests/spanish_train_sample.json,/manifests/french_train_sample.json,/manifests/russian_train_sample.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       shift:
#         prob: 0.5
#         min_shift_ms: -10.0
#         max_shift_ms: 10.0
#       white_noise:
#         prob: 0.5
#         min_level: -90
#         max_level: -46
#         norm: true
#       noise:
#         prob: 0.5
#         manifest_path: /manifests/noise_0_1_musan_fs.json
#         min_snr_db: 0
#         max_snr_db: 30
#         max_gain_db: 300.0
#         norm: true
#       gain:
#         prob: 0.5
#         min_gain_dbfs: -10.0
#         max_gain_dbfs: 10.0
#         norm: true
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:08 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/ami_dev_0.63.json,/manifests/freesound_background_dev.json,/manifests/freesound_laughter_dev.json,/manifests/ch120_moved_0.63.json,/manifests/fisher_2005_500_speech_sampled.json,/manifests/google_dev_manifest.json,/manifests/musan_music_dev.json,/manifests/mandarin_dev.json,/manifests/german_dev.json,/manifests/spanish_dev.json,/manifests/french_dev.json,/manifests/russian_dev.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: false
#     val_loss_idx: 0
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:08 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 128
#     shuffle: false
#     test_loss_idx: 0
# [NeMo I 2023-10-26 17:26:08 features:289] PADDING: 16
# [NeMo I 2023-10-26 17:26:09 save_restore_connector:249] Model EncDecClassificationModel was successfully restored from /home/taejinp/gdrive/model/VAD_models/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo.
# [NeMo I 2023-10-26 17:26:09 clustering_diarizer:120] VAD model loaded locally from /home/taejinp/gdrive/model/VAD_models/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo
# [NeMo W 2023-10-26 17:26:09 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:09 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2023-10-26 17:26:09 features:289] PADDING: 16
# [NeMo I 2023-10-26 17:26:09 save_restore_connector:249] Model EncDecSpeakerLabelModel was successfully restored from /home/taejinp/Downloads/titanet_target_fixed/titanet-l.nemo.
# [NeMo I 2023-10-26 17:26:09 clustering_diarizer:145] Speaker Model restored locally from /home/taejinp/Downloads/titanet_target_fixed/titanet-l.nemo
# [NeMo I 2023-10-26 17:26:09 speaker_utils:93] Number of files to diarize: 4
# [NeMo W 2023-10-26 17:26:09 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/ami_train_0.63.json,/manifests/freesound_background_train.json,/manifests/freesound_laughter_train.json,/manifests/fisher_2004_background.json,/manifests/fisher_2004_speech_sampled.json,/manifests/google_train_manifest.json,/manifests/icsi_all_0.63.json,/manifests/musan_freesound_train.json,/manifests/musan_music_train.json,/manifests/musan_soundbible_train.json,/manifests/mandarin_train_sample.json,/manifests/german_train_sample.json,/manifests/spanish_train_sample.json,/manifests/french_train_sample.json,/manifests/russian_train_sample.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       shift:
#         prob: 0.5
#         min_shift_ms: -10.0
#         max_shift_ms: 10.0
#       white_noise:
#         prob: 0.5
#         min_level: -90
#         max_level: -46
#         norm: true
#       noise:
#         prob: 0.5
#         manifest_path: /manifests/noise_0_1_musan_fs.json
#         min_snr_db: 0
#         max_snr_db: 30
#         max_gain_db: 300.0
#         norm: true
#       gain:
#         prob: 0.5
#         min_gain_dbfs: -10.0
#         max_gain_dbfs: 10.0
#         norm: true
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:09 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/ami_dev_0.63.json,/manifests/freesound_background_dev.json,/manifests/freesound_laughter_dev.json,/manifests/ch120_moved_0.63.json,/manifests/fisher_2005_500_speech_sampled.json,/manifests/google_dev_manifest.json,/manifests/musan_music_dev.json,/manifests/mandarin_dev.json,/manifests/german_dev.json,/manifests/spanish_dev.json,/manifests/french_dev.json,/manifests/russian_dev.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: false
#     val_loss_idx: 0
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:09 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 128
#     shuffle: false
#     test_loss_idx: 0
# [NeMo I 2023-10-26 17:26:09 features:289] PADDING: 16
# [NeMo I 2023-10-26 17:26:09 save_restore_connector:249] Model EncDecClassificationModel was successfully restored from /home/taejinp/gdrive/model/VAD_models/mVAD_lin_marblenet-3x2x64-4N-256bs-50e-0.01lr-0.001wd.nemo.
# [NeMo I 2023-10-26 17:26:12 mixins:170] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2023-10-26 17:26:12 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /data/asr_datasets_prebuilt/RIVA_ASR_SET_3.0_tarred/tarred_audio_manifest.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: true
#     is_tarred: true
#     tarred_audio_filepaths: /data/asr_datasets_prebuilt/RIVA_ASR_SET_3.0_tarred/audio__OP_0..4095_CL_.tar
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20.0
#     min_duration: 0.1
#     shuffle_n: 1024
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:12 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /data/Jasper_NEMO_manifests/librivox-test-other.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2023-10-26 17:26:12 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2023-10-26 17:26:12 features:289] PADDING: 0
# [NeMo I 2023-10-26 17:26:13 save_restore_connector:249] Model EncDecCTCModelBPE was successfully restored from /home/taejinp/gdrive/model/ASR_models/Conformer-CTC-BPE_large_Riva_ASR_set_3.0_ep60.nemo.
# [NeMo W 2023-10-26 17:26:13 decoder_timestamps_utils:66] `ctc_decode` was set to True. Note that this is ignored.
# [NeMo I 2023-10-26 17:26:13 features:289] PADDING: 0
# [NeMo I 2023-10-26 17:26:14 features:289] PADDING: 0
# [NeMo I 2023-10-26 17:26:14 features:289] PADDING: 0

# %% [markdown]
# Let's run simulated audio stream to check if streaming system is working properly. After you initiate the following function and while the function is running, you can check the transcription is being generated in realtime.  The path is ./streaming_diar_output/print_script.sh, and this can be viewed using "streaming_diarization_viewer.ipynb"

# %%
import ipywidgets
import time
box_layout = ipywidgets.Layout(height="500px", width="90%")
widget = ipywidgets.Textarea(value='', disabled=True, layout=box_layout)
display(widget)  # display widget
# Out:
# Textarea(value='', disabled=True, layout=Layout(height='500px', width='90%'))

# %%
diar.uniq_id = cfg.diarizer.simulation_uniq_id
online_diar_asr.get_audio_rttm_map(diar.uniq_id)
diar.single_audio_file_path = diar.AUDIO_RTTM_MAP[diar.uniq_id]['audio_filepath']
online_diar_asr.rttm_file_path = diar.AUDIO_RTTM_MAP[diar.uniq_id]['rttm_filepath']

diar._init_segment_variables()
diar.device = online_diar_asr.device
write_txt(f"{diar._out_dir}/print_script.sh", "")

if cfg.diarizer.asr.parameters.streaming_simulation == True:
    samplerate, sdata = wavfile.read(diar.single_audio_file_path)
    if  diar.AUDIO_RTTM_MAP[diar.uniq_id]['offset'] and diar.AUDIO_RTTM_MAP[diar.uniq_id]['duration']:
        
        offset = samplerate*diar.AUDIO_RTTM_MAP[diar.uniq_id]['offset']
        duration = samplerate*diar.AUDIO_RTTM_MAP[diar.uniq_id]['duration']
        stt, end = int(offset), int(offset + duration)
        sdata = sdata[stt:end]

    for index in range(int(np.floor(sdata.shape[0]/online_diar_asr.n_frame_len))):
        shift = online_diar_asr.CHUNK_SIZE
        sample_audio = sdata[shift*index:shift*(index+1)]
        online_diar_asr.buffer_counter = index
        online_diar_asr.streaming_step(sample_audio)
        
        widget.value += f" update {index}"
        fp = open(f'{diar._out_dir}/print_script.sh','r').read()
        widget.value = fp
else:
    isTorch = torch.cuda.is_available()
    iface = gr.Interface(
    fn=online_diar_asr.audio_queue_launcher,
    inputs=[
        gr.Audio(source="microphone", type="numpy", streaming=True), 
        "state",
    ],
    outputs=[
        "textbox",
        "state",
    ],
    layout="horizontal",
    theme="huggingface",
    title=f"NeMo Streaming Conformer CTC Large - English, CUDA:{isTorch}",
    description="Demo for English speech recognition using Conformer Transducers",
    allow_flagging='never',
    live=True,
    )
    iface.launch(share=True)
# Out:
# [NeMo W 2023-10-26 17:26:14 nemo_logging:349] /home/taejinp/anaconda3/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: `layout` parameter is deprecated, and it has no effect
#       warnings.warn(value)
#
# [NeMo W 2023-10-26 17:26:14 nemo_logging:349] /home/taejinp/anaconda3/lib/python3.9/site-packages/gradio/interface.py:328: UserWarning: Currently, only the 'default' theme is supported.
#       warnings.warn("Currently, only the 'default' theme is supported.")
# IMPORTANT: You are using gradio version 3.4.0, however version 3.14.0 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7860
# [NeMo I 2023-10-26 17:26:35 diarization_utils:1381] 2051.99ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:35 diarization_utils:1381] 37.81ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:35 online_diarizer:56] 0.07ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:35 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:35 diarization_utils:2020] Total ASR and Diarization ETA: 2.974 comp ETA 2.975
# [NeMo I 2023-10-26 17:26:36 diarization_utils:1381] 142.35ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:36 diarization_utils:1381] 32.81ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:36 online_diarizer:56] 0.06ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:36 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:36 diarization_utils:2020] Total ASR and Diarization ETA: 0.187 comp ETA 0.188
# [NeMo I 2023-10-26 17:26:36 diarization_utils:1381] 17.42ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:36 diarization_utils:1381] 35.50ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:36 online_diarizer:56] 0.06ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:36 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:36 diarization_utils:2020] Total ASR and Diarization ETA: 0.064 comp ETA 0.064
# [NeMo I 2023-10-26 17:26:36 diarization_utils:1381] 42.37ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:36 diarization_utils:1381] 35.40ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:36 online_diarizer:56] 0.05ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:36 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:36 diarization_utils:2020] Total ASR and Diarization ETA: 0.087 comp ETA 0.087
# [NeMo I 2023-10-26 17:26:37 diarization_utils:1381] 16.60ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:37 diarization_utils:1381] 39.50ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:37 online_diarizer:56] 0.06ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:37 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:37 diarization_utils:2020] Total ASR and Diarization ETA: 0.069 comp ETA 0.070
# [NeMo I 2023-10-26 17:26:38 diarization_utils:1381] 13.90ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:38 diarization_utils:1381] 34.64ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:38 online_diarizer:56] 0.06ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:38 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:38 diarization_utils:2020] Total ASR and Diarization ETA: 0.062 comp ETA 0.062
# [NeMo I 2023-10-26 17:26:39 diarization_utils:1381] 7.84ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:39 diarization_utils:1381] 31.28ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 11.80ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 12.84ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 12.74ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 13.87ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 27.39ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 28.47ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 213.41ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:39 online_diarizer:56] 276.18ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:39 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:39 diarization_utils:2020] Total ASR and Diarization ETA: 0.329 comp ETA 0.329
# [NeMo I 2023-10-26 17:26:40 diarization_utils:1381] 14.47ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:40 diarization_utils:1381] 34.03ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 0.00ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 11.04ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 12.52ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 10.55ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 11.51ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 229.41ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:40 online_diarizer:56] 260.28ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:40 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:40 diarization_utils:2020] Total ASR and Diarization ETA: 0.331 comp ETA 0.331
# [NeMo I 2023-10-26 17:26:41 diarization_utils:1381] 13.25ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:41 diarization_utils:1381] 32.85ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 10.73ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 11.84ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 10.02ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 10.94ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 8.12ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 9.66ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 12.03ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:41 online_diarizer:56] 52.50ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:41 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:41 diarization_utils:2020] Total ASR and Diarization ETA: 0.118 comp ETA 0.118
# [NeMo I 2023-10-26 17:26:42 diarization_utils:1381] 7.67ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:42 diarization_utils:1381] 42.79ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 18.52ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 19.49ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 10.61ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 12.12ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 20.06ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 21.38ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 6.81ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:42 online_diarizer:56] 68.53ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:42 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:42 diarization_utils:2020] Total ASR and Diarization ETA: 0.133 comp ETA 0.133
# [NeMo I 2023-10-26 17:26:43 diarization_utils:1381] 14.22ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:43 diarization_utils:1381] 34.09ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 8.72ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 9.83ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 7.77ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 9.06ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 7.97ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 8.82ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 16.50ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:43 online_diarizer:56] 52.07ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:43 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:43 diarization_utils:2020] Total ASR and Diarization ETA: 0.116 comp ETA 0.117
# [NeMo I 2023-10-26 17:26:44 diarization_utils:1381] 16.75ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:44 diarization_utils:1381] 41.78ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 9.24ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 10.38ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 8.44ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 9.41ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 8.08ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 9.09ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 4.81ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:44 online_diarizer:56] 40.03ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:44 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:44 diarization_utils:2020] Total ASR and Diarization ETA: 0.116 comp ETA 0.116
# [NeMo I 2023-10-26 17:26:45 diarization_utils:1381] 11.14ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:45 diarization_utils:1381] 34.56ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 9.12ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 9.92ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 8.33ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 9.09ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 8.45ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 9.19ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 5.09ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:45 online_diarizer:56] 39.12ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:45 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:45 diarization_utils:2020] Total ASR and Diarization ETA: 0.102 comp ETA 0.102
# [NeMo I 2023-10-26 17:26:46 diarization_utils:1381] 16.91ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:46 diarization_utils:1381] 37.57ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 16.51ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 17.42ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 10.74ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 11.90ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 8.66ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 9.83ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 5.60ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:46 online_diarizer:56] 51.53ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:46 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:46 diarization_utils:2020] Total ASR and Diarization ETA: 0.122 comp ETA 0.122
# [NeMo I 2023-10-26 17:26:47 diarization_utils:1381] 14.74ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:47 diarization_utils:1381] 41.39ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 8.97ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 10.63ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 15.91ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 17.24ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 8.98ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 9.97ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 5.09ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:47 online_diarizer:56] 50.99ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:47 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:47 diarization_utils:2020] Total ASR and Diarization ETA: 0.127 comp ETA 0.127
# [NeMo I 2023-10-26 17:26:48 diarization_utils:1381] 7.74ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:48 diarization_utils:1381] 33.25ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 11.42ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 12.33ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 8.81ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 9.80ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 14.38ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 15.58ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 23.23ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:48 online_diarizer:56] 67.91ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:48 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:48 diarization_utils:2020] Total ASR and Diarization ETA: 0.125 comp ETA 0.125
# [NeMo I 2023-10-26 17:26:49 diarization_utils:1381] 14.91ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:49 diarization_utils:1381] 34.69ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 9.15ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 10.28ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 15.45ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 16.44ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 10.22ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 11.66ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 10.78ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:49 online_diarizer:56] 59.92ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:49 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:49 diarization_utils:2020] Total ASR and Diarization ETA: 0.126 comp ETA 0.126
# [NeMo I 2023-10-26 17:26:50 diarization_utils:1381] 13.09ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:50 diarization_utils:1381] 44.72ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 8.82ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 9.65ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 7.95ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 9.07ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 18.76ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 19.85ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 8.69ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:50 online_diarizer:56] 53.81ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:50 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:50 diarization_utils:2020] Total ASR and Diarization ETA: 0.131 comp ETA 0.131
# [NeMo I 2023-10-26 17:26:51 diarization_utils:1381] 7.63ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:51 diarization_utils:1381] 32.27ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 18.43ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 20.10ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 17.52ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 18.73ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 11.73ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 12.80ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 5.70ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:51 online_diarizer:56] 64.57ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:51 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:51 diarization_utils:2020] Total ASR and Diarization ETA: 0.116 comp ETA 0.116
# [NeMo I 2023-10-26 17:26:53 diarization_utils:1381] 9.08ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:53 diarization_utils:1381] 39.06ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 16.14ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 17.93ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 9.69ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 11.10ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 8.75ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 9.88ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 5.36ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:53 online_diarizer:56] 52.63ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:53 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:53 diarization_utils:2020] Total ASR and Diarization ETA: 0.118 comp ETA 0.118
# [NeMo I 2023-10-26 17:26:54 diarization_utils:1381] 15.94ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:54 diarization_utils:1381] 39.01ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 8.73ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 10.13ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 7.89ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 8.96ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 7.98ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 9.44ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 25.31ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:54 online_diarizer:56] 61.16ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:54 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:54 diarization_utils:2020] Total ASR and Diarization ETA: 0.132 comp ETA 0.133
# [NeMo I 2023-10-26 17:26:55 diarization_utils:1381] 15.94ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:55 diarization_utils:1381] 37.48ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 8.66ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 9.74ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 17.99ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 19.58ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 16.21ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 17.86ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 9.21ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:55 online_diarizer:56] 65.53ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:55 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:55 diarization_utils:2020] Total ASR and Diarization ETA: 0.135 comp ETA 0.135
# [NeMo I 2023-10-26 17:26:56 diarization_utils:1381] 7.51ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:56 diarization_utils:1381] 34.27ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 8.68ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 9.47ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 11.86ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 12.96ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 15.21ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 16.49ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 9.06ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:56 online_diarizer:56] 55.45ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:56 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:56 diarization_utils:2020] Total ASR and Diarization ETA: 0.114 comp ETA 0.114
# [NeMo I 2023-10-26 17:26:57 diarization_utils:1381] 15.71ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:57 diarization_utils:1381] 35.12ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 8.98ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 10.00ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 13.57ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 14.50ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 11.37ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 12.89ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 13.94ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:57 online_diarizer:56] 59.38ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:57 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:57 diarization_utils:2020] Total ASR and Diarization ETA: 0.125 comp ETA 0.125
# [NeMo I 2023-10-26 17:26:58 diarization_utils:1381] 17.36ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:58 diarization_utils:1381] 42.52ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 8.94ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 10.60ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 19.27ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 20.93ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 23.24ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 24.73ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 15.10ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:58 online_diarizer:56] 84.09ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:58 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:58 diarization_utils:2020] Total ASR and Diarization ETA: 0.161 comp ETA 0.161
# [NeMo I 2023-10-26 17:26:59 diarization_utils:1381] 7.49ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:26:59 diarization_utils:1381] 31.63ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 8.57ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 9.25ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 7.75ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 8.35ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 7.85ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 8.54ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 48.45ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:26:59 online_diarizer:56] 82.20ms 'diarize_step'
# [NeMo I 2023-10-26 17:26:59 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:26:59 diarization_utils:2020] Total ASR and Diarization ETA: 0.136 comp ETA 0.136
# [NeMo I 2023-10-26 17:27:07 diarization_utils:1381] 17.30ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:07 diarization_utils:1381] 33.15ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 8.39ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 9.03ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 7.43ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 8.18ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 19.88ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 20.89ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 10.30ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:07 online_diarizer:56] 54.79ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:07 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:07 diarization_utils:2020] Total ASR and Diarization ETA: 0.119 comp ETA 0.119
# [NeMo I 2023-10-26 17:27:08 diarization_utils:1381] 7.66ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:08 diarization_utils:1381] 43.58ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 11.94ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 13.10ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 9.08ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 10.19ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 7.97ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 9.06ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 9.16ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:08 online_diarizer:56] 49.43ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:08 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:08 diarization_utils:2020] Total ASR and Diarization ETA: 0.113 comp ETA 0.114
# [NeMo I 2023-10-26 17:27:09 diarization_utils:1381] 16.36ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:09 diarization_utils:1381] 41.05ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 10.17ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 11.58ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 13.79ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 15.05ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 10.05ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 11.18ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 9.50ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:09 online_diarizer:56] 57.62ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:09 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:09 diarization_utils:2020] Total ASR and Diarization ETA: 0.133 comp ETA 0.133
# [NeMo I 2023-10-26 17:27:11 diarization_utils:1381] 11.10ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:11 diarization_utils:1381] 33.14ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 8.97ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 10.47ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 16.12ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 17.38ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 12.71ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 14.04ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 14.77ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:11 online_diarizer:56] 66.59ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:11 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 1
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:11 diarization_utils:2020] Total ASR and Diarization ETA: 0.126 comp ETA 0.127
# [NeMo I 2023-10-26 17:27:12 diarization_utils:1381] 14.58ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:12 diarization_utils:1381] 33.71ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 8.74ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 10.02ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 8.14ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 9.04ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 8.29ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 9.35ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 44.29ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:12 online_diarizer:56] 81.46ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:12 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:12 diarization_utils:2020] Total ASR and Diarization ETA: 0.147 comp ETA 0.147
# [NeMo I 2023-10-26 17:27:13 diarization_utils:1381] 252.86ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:13 diarization_utils:1381] 36.93ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 8.71ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 9.69ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 10.85ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 12.14ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 9.14ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 10.58ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 18.96ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:13 online_diarizer:56] 60.51ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:13 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:13 diarization_utils:2020] Total ASR and Diarization ETA: 0.366 comp ETA 0.366
# [NeMo I 2023-10-26 17:27:14 diarization_utils:1381] 7.84ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:14 diarization_utils:1381] 35.69ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 9.06ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 10.36ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 8.10ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 9.32ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 18.54ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 19.61ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 14.82ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 63.61ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:14 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:14 diarization_utils:2020] Total ASR and Diarization ETA: 0.122 comp ETA 0.123
# [NeMo I 2023-10-26 17:27:14 diarization_utils:1381] 16.43ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:14 diarization_utils:1381] 34.54ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 12.84ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 14.02ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 15.70ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 16.76ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 14.54ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 16.14ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 11.90ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:14 online_diarizer:56] 66.96ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:14 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:14 diarization_utils:2020] Total ASR and Diarization ETA: 0.130 comp ETA 0.130
# [NeMo I 2023-10-26 17:27:15 diarization_utils:1381] 16.63ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:15 diarization_utils:1381] 34.22ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 9.02ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 9.84ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 7.90ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 8.84ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 8.18ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 9.47ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 11.49ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:15 online_diarizer:56] 46.16ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:15 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:15 diarization_utils:2020] Total ASR and Diarization ETA: 0.111 comp ETA 0.111
# [NeMo I 2023-10-26 17:27:16 diarization_utils:1381] 7.78ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:16 diarization_utils:1381] 31.46ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 19.04ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 20.06ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 15.15ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 16.55ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 20.71ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 22.52ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 66.54ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:16 online_diarizer:56] 134.67ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:16 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:16 diarization_utils:2020] Total ASR and Diarization ETA: 0.188 comp ETA 0.188
# [NeMo I 2023-10-26 17:27:17 diarization_utils:1381] 8.17ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:17 diarization_utils:1381] 36.04ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 10.54ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 11.69ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 8.01ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 9.11ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 8.03ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 9.42ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 20.87ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:17 online_diarizer:56] 60.93ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:17 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:17 diarization_utils:2020] Total ASR and Diarization ETA: 0.119 comp ETA 0.119
# [NeMo I 2023-10-26 17:27:18 diarization_utils:1381] 14.70ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:18 diarization_utils:1381] 36.50ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 9.26ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 10.37ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 8.17ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 9.21ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 20.09ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 21.67ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 15.10ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:18 online_diarizer:56] 65.05ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:18 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:18 diarization_utils:2020] Total ASR and Diarization ETA: 0.132 comp ETA 0.132
# [NeMo I 2023-10-26 17:27:19 diarization_utils:1381] 15.98ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:19 diarization_utils:1381] 33.00ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 10.00ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 11.16ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 7.80ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 8.51ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 7.98ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 9.28ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 12.65ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:19 online_diarizer:56] 48.15ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:19 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:19 diarization_utils:2020] Total ASR and Diarization ETA: 0.115 comp ETA 0.115
# [NeMo I 2023-10-26 17:27:20 diarization_utils:1381] 14.37ms 'run_VAD_decoder_step'
# [NeMo I 2023-10-26 17:27:20 diarization_utils:1381] 32.60ms 'run_ASR_decoder_step'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 8.72ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 9.93ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 8.15ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 9.31ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 18.52ms '_run_embedding_extractor'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 19.51ms '_extract_online_embeddings'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 14.86ms '_perform_online_clustering'
# [NeMo I 2023-10-26 17:27:20 online_diarizer:56] 61.18ms 'diarize_step'
# [NeMo I 2023-10-26 17:27:20 diarization_utils:899] Creating results for Session: citadel_ken n_spk: 2
# OUTPUT DIR: /home/taejinp/projects/run_time/streaming_diar_output_univ/print_script.sh
# [NeMo I 2023-10-26 17:27:20 diarization_utils:2020] Total ASR and Diarization ETA: 0.125 comp ETA 0.125
# *** Failed to connect to ec2.gradio.app:22: [Errno 110] Connection timed out
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/gradio/tunneling.py:74, in create_tunnel(payload, local_server, local_server_port)
#      73         warnings.simplefilter("ignore")
# ---> 74         client.connect(
#      75             hostname=payload["host"],
#      76             port=int(payload["port"]),
#      77             username=payload["user"],
#      78             pkey=paramiko.RSAKey.from_private_key(StringIO(payload["key"])),
#      79         )
#      80 except Exception as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/paramiko/client.py:358, in SSHClient.connect(self, hostname, port, username, password, pkey, key_filename, timeout, allow_agent, look_for_keys, compress, sock, gss_auth, gss_kex, gss_deleg_creds, gss_host, banner_timeout, auth_timeout, gss_trust_dns, passphrase, disabled_algorithms, transport_factory)
#     357         pass
# --> 358 retry_on_signal(lambda: sock.connect(addr))
#     359 # Break out of the loop on success
#
# File ~/anaconda3/lib/python3.9/site-packages/paramiko/util.py:279, in retry_on_signal(function)
#     278 try:
# --> 279     return function()
#     280 except EnvironmentError as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/paramiko/client.py:358, in SSHClient.connect.<locals>.<lambda>()
#     357         pass
# --> 358 retry_on_signal(lambda: sock.connect(addr))
#     359 # Break out of the loop on success
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[10], line 47
#      30 iface = gr.Interface(
#      31 fn=online_diar_asr.audio_queue_launcher,
#      32 inputs=[
#    (...)
#      45 live=True,
#      46 )
# ---> 47 iface.launch(share=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/blocks.py:1105, in Blocks.launch(self, inline, inbrowser, share, debug, enable_queue, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, show_tips, height, width, encrypt, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, quiet, show_api, _frontend)
#    1104 if self.share_url is None:
# -> 1105     share_url = networking.setup_tunnel(self.server_port, None)
#    1106     self.share_url = share_url
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/networking.py:167, in setup_tunnel(local_server_port, endpoint)
#     166     payload = response.json()[0]
# --> 167     return create_tunnel(payload, LOCALHOST_NAME, local_server_port)
#     168 except Exception as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/tunneling.py:82, in create_tunnel(payload, local_server, local_server_port)
#      81     print(f'*** Failed to connect to {payload["host"]}:{payload["port"]}: {e}')
# ---> 82     sys.exit(1)
#      84 verbose(
#      85     f'Now forwarding remote port {payload["remote_port"]}'
#      86     f"to {local_server}:{local_server_port} ..."
#      87 )
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2047, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044 if exception_only:
#    2045     stb = ['An exception has occurred, use %tb to see '
#    2046            'the full traceback.\n']
# -> 2047     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2048                                                      value))
#    2049 else:
#    2050     try:
#    2051         # Exception classes can customise their traceback - we
#    2052         # use this in IPython.parallel for exceptions occurring
#    2053         # in the engines. This should return a list of strings.
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:585, in ListTB.get_exception_only(self, etype, value)
#     577 def get_exception_only(self, etype, value):
#     578     """Only print the exception type and message, without a traceback.
#     579
#     580     Parameters
#    (...)
#     583     value : exception value
#     584     """
# --> 585     return ListTB.structured_traceback(self, etype, value)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:452, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     449     chained_exc_ids.add(id(exception[1]))
#     450     chained_exceptions_tb_offset = 0
#     451     out_list = (
# --> 452         self.structured_traceback(
#     453             etype, evalue, (etb, chained_exc_ids),
#     454             chained_exceptions_tb_offset, context)
#     455         + chained_exception_message
#     456         + out_list)
#     458 return out_list
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:1118, in AutoFormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1116 else:
#    1117     self.tb = tb
# -> 1118 return FormattedTB.structured_traceback(
#    1119     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:1012, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1009 mode = self.mode
#    1010 if mode in self.verbose_modes:
#    1011     # Verbose modes need a full traceback
# -> 1012     return VerboseTB.structured_traceback(
#    1013         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1014     )
#    1015 elif mode == 'Minimal':
#    1016     return ListTB.get_exception_only(self, etype, value)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:865, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#     856 def structured_traceback(
#     857     self,
#     858     etype: type,
#    (...)
#     862     number_of_lines_of_context: int = 5,
#     863 ):
#     864     """Return a nice text document describing the traceback."""
# --> 865     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#     866                                                            tb_offset)
#     868     colors = self.Colors  # just a shorthand + quicker name lookup
#     869     colorsnormal = colors.Normal  # used a lot
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:799, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     796 assert isinstance(tb_offset, int)
#     797 head = self.prepare_header(etype, self.long_header)
#     798 records = (
# --> 799     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     800 )
#     802 frames = []
#     803 skipped = 0
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/ultratb.py:854, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#     848     formatter = None
#     849 options = stack_data.Options(
#     850     before=before,
#     851     after=after,
#     852     pygments_formatter=formatter,
#     853 )
# --> 854 return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#
# File ~/.local/lib/python3.9/site-packages/stack_data/core.py:578, in FrameInfo.stack_data(cls, frame_or_tb, options, collapse_repeated_frames)
#     562 @classmethod
#     563 def stack_data(
#     564         cls,
#    (...)
#     568         collapse_repeated_frames: bool = True
#     569 ) -> Iterator[Union['FrameInfo', RepeatedFrames]]:
#     570     """
#     571     An iterator of FrameInfo and RepeatedFrames objects representing
#     572     a full traceback or stack. Similar consecutive frames are collapsed into RepeatedFrames
#    (...)
#     576     and optionally an Options object to configure.
#     577     """
# --> 578     stack = list(iter_stack(frame_or_tb))
#     580     # Reverse the stack from a frame so that it's in the same order
#     581     # as the order from a traceback, which is the order of a printed
#     582     # traceback when read top to bottom (most recent call last)
#     583     if is_frame(frame_or_tb):
#
# File ~/.local/lib/python3.9/site-packages/stack_data/utils.py:97, in iter_stack(frame_or_tb)
#      95 while frame_or_tb:
#      96     yield frame_or_tb
# ---> 97     if is_frame(frame_or_tb):
#      98         frame_or_tb = frame_or_tb.f_back
#      99     else:
#
# File ~/.local/lib/python3.9/site-packages/stack_data/utils.py:90, in is_frame(frame_or_tb)
#      89 def is_frame(frame_or_tb: Union[FrameType, TracebackType]) -> bool:
# ---> 90     assert_(isinstance(frame_or_tb, (types.FrameType, types.TracebackType)))
#      91     return isinstance(frame_or_tb, (types.FrameType,))
#
# File ~/.local/lib/python3.9/site-packages/stack_data/utils.py:176, in assert_(condition, error)
#     174 if isinstance(error, str):
#     175     error = AssertionError(error)
# --> 176 raise error
#
# AssertionError:

# %% [markdown]
# Now, go to streaming_diarization_viewer.ipynb and check the realtime output.

# %%
while True:
    fp = open(f'{diar._out_dir}/print_script.sh','r').read()
    widget.value = fp
    time.sleep(0.1)

# %%
# cfg.diarizer.asr.parameters.streaming_simulation=False
# cfg.diarizer.asr.parameters.enforce_real_time=False
# online_diar_asr = OnlineDiarWithASR(cfg=cfg)
# diar = online_diar_asr.diar
# write_txt(f"{diar._out_dir}/print_script.sh", "")

# diar.uniq_id = cfg.diarizer.simulation_uniq_id 
# diar.single_audio_file_path = AUDIO_RTTM_MAP[diar.uniq_id]['audio_filepath']
# diar.rttm_file_path = AUDIO_RTTM_MAP[diar.uniq_id]['rttm_filepath']
# # diar.rttm_file_path = None # DER calculation slows down online diarization speed
# diar._init_segment_variables()

# %%
# import ipywidgets
# import time
# box_layout = ipywidgets.Layout(height="500px", width="90%")
# widget_gradio = ipywidgets.Textarea(value='', disabled=True, layout=box_layout)
# display(widget_gradio)  # display widget
# write_txt(f"{diar._out_dir}/print_script.sh", "")

# %%
# isTorch = torch.cuda.is_available()
# iface = gr.Interface(
#     fn=online_diar_asr.audio_queue_launcher,
#     inputs=[
#         gr.Audio(source="microphone", type="numpy", streaming=True), 
#         "state",
#     ],
#     outputs=[
#         "textbox",
#         "state",
#     ],
#     layout="horizontal",
#     theme="huggingface",
#     title=f"NeMo Streaming Conformer CTC Large - English, CUDA:{isTorch}",
#     description="Demo for English speech recognition using Conformer Transducers",
#     allow_flagging='never',
#     live=True,
# )
# iface.launch(share=True)

# for index in range(100000000):
#     widget_gradio.value += f" update {index}"
#     fp = open(f'{diar._out_dir}/print_script.sh','r').read()
#     widget_gradio.value = fp
#     time.sleep(0.01)
