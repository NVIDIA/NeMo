# %% [markdown]
# # Voicebox Data Preparation with Montreal Forced Aligner (MFA)
# This is the tutorial of preparing manifests of training/validation dataset.
#
# Since Voicebox requires frame-level alignment with phonemes as input, we need to prepare alignments for each utterance in the dataset.
#
# **We recommand [install MFA environment with conda](https://montreal-forced-aligner.readthedocs.io/en/latest/installation.html#general-installation) inside the NeMo docker**.

# %% [markdown]
# ## Install [Miniconda](https://docs.anaconda.com/miniconda/#quick-command-line-install)

# %%
# Install miniconda from source
# !mkdir -p ~/miniconda3
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# !bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# !rm ~/miniconda3/miniconda.sh

# Add conda to shell initialization (choose your shell)
!~/miniconda3/bin/conda init bash
!~/miniconda3/bin/conda init zsh
# Out:
# --2024-08-29 06:03:28--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148981743 (142M) [application/octet-stream]
# Saving to: ‘/root/miniconda3/miniconda.sh’
#
# /root/miniconda3/mi 100%[===================>] 142.08M  62.9MB/s    in 2.3s
#
# 2024-08-29 06:03:30 (62.9 MB/s) - ‘/root/miniconda3/miniconda.sh’ saved [148981743/148981743]
#
# PREFIX=/root/miniconda3
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /root/miniconda3
# no change     /root/miniconda3/condabin/conda
# no change     /root/miniconda3/bin/conda
# no change     /root/miniconda3/bin/conda-env
# no change     /root/miniconda3/bin/activate
# no change     /root/miniconda3/bin/deactivate
# no change     /root/miniconda3/etc/profile.d/conda.sh
# no change     /root/miniconda3/etc/fish/conf.d/conda.fish
# no change     /root/miniconda3/shell/condabin/Conda.psm1
# no change     /root/miniconda3/shell/condabin/conda-hook.ps1
# no change     /root/miniconda3/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /root/miniconda3/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# no change     /root/miniconda3/condabin/conda
# no change     /root/miniconda3/bin/conda
# no change     /root/miniconda3/bin/conda-env
# no change     /root/miniconda3/bin/activate
# no change     /root/miniconda3/bin/deactivate
# no change     /root/miniconda3/etc/profile.d/conda.sh
# no change     /root/miniconda3/etc/fish/conf.d/conda.fish
# no change     /root/miniconda3/shell/condabin/Conda.psm1
# no change     /root/miniconda3/shell/condabin/conda-hook.ps1
# no change     /root/miniconda3/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /root/miniconda3/etc/profile.d/conda.csh
# modified      /root/.zshrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %% [markdown]
# Restart the shell environment (reload window if using vscode) to enable the conda command, then run:

# %%
! source ~/.bashrc
! echo $PATH

# Set default conda activation to false, so that it doesn't interfere with the NeMo docker environment
# !conda config --set auto_activate_base false
# Out:
# /usr/bin:/root/.local/bin:/vscode/vscode-server/bin/linux-x64/fee1edb8d6d72a0ddff41e5f71a671c23ed924b9/bin/remote-cli:/root/miniconda3/bin:/root/miniconda3/condabin:/usr/local/nvm/versions/node/v16.20.2/bin:/usr/local/lib/python3.10/dist-packages/torch_tensorrt/bin:/usr/local/mpi/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/local/ucx/bin:/opt/tensorrt/bin:/usr/local/cmake/bin:/usr/local/cmake/bin:/usr/local/cmake/bin:/usr/local/cmake/bin:/vscode/vscode-server/bin/linux-x64/fee1edb8d6d72a0ddff41e5f71a671c23ed924b9/bin/remote-cli:/root/miniconda3/bin:/root/miniconda3/condabin:/usr/local/nvm/versions/node/v16.20.2/bin:/usr/local/lib/python3.10/dist-packages/torch_tensorrt/bin:/usr/local/mpi/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/local/ucx/bin:/opt/tensorrt/bin:/usr/local/cmake/bin:/usr/local/cmake/bin:/usr/local/cmake/bin:/usr/local/cmake/bin:/usr/local/cmake/bin

# %% [markdown]
# ## Install MFA

# %%
# create new conda environment and install montreal forced aligner
# !conda create -n aligner -c conda-forge montreal-forced-aligner -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3/envs/aligner
#
#   added / updated specs:
#     - montreal-forced-aligner
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     atk-1.0-2.38.0             |       h04ea711_2         348 KB  conda-forge
#     audioread-3.0.1            |   py39hf3d152e_1          36 KB  conda-forge
#     baumwelch-0.3.9            |       h434a139_3         368 KB  conda-forge
#     biopython-1.79             |   py39hb9d737c_3         2.6 MB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     brotli-python-1.1.0        |   py39h3d6467e_1         342 KB  conda-forge
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
#     cairo-1.18.0               |       hebfffa5_3         961 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     cffi-1.17.0                |   py39h49a4b6b_0         235 KB  conda-forge
#     charset-normalizer-3.3.2   |     pyhd8ed1ab_0          46 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     colorama-0.4.6             |     pyhd8ed1ab_0          25 KB  conda-forge
#     contourpy-1.2.1            |   py39h7633fee_0         236 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     dataclassy-1.0.1           |     pyhd8ed1ab_0          31 KB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     decorator-5.1.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     expat-2.6.2                |       h59595ed_0         134 KB  conda-forge
#     ffmpeg-7.0.2               | gpl_h226ea3b_102         9.8 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_2         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.53.1           |   py39hcd6043d_0         2.2 MB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     gettext-0.22.5             |       he02047a_3         468 KB  conda-forge
#     gettext-tools-0.22.5       |       he02047a_3         2.6 MB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     gnutls-3.8.7               |       h32866dd_0         1.8 MB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     graphviz-12.0.0            |       hba01fac_0         2.2 MB  conda-forge
#     greenlet-3.0.3             |   py39h3d6467e_0         205 KB  conda-forge
#     gtk2-2.24.33               |       h6470451_5         6.2 MB  conda-forge
#     gts-0.7.6                  |       h977cf35_4         311 KB  conda-forge
#     h2-4.1.0                   |     pyhd8ed1ab_0          46 KB  conda-forge
#     harfbuzz-9.0.0             |       hda332d3_1         1.5 MB  conda-forge
#     hdbscan-0.8.38.post1       |   py39h988be6c_1         596 KB  conda-forge
#     hpack-4.0.0                |     pyh9f0ad1d_0          25 KB  conda-forge
#     hyperframe-6.0.1           |     pyhd8ed1ab_0          14 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     idna-3.8                   |     pyhd8ed1ab_0          48 KB  conda-forge
#     importlib-metadata-8.4.0   |     pyha770c72_0          28 KB  conda-forge
#     importlib-resources-6.4.4  |     pyhd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.4  |     pyhd8ed1ab_0          32 KB  conda-forge
#     joblib-1.4.2               |     pyhd8ed1ab_0         215 KB  conda-forge
#     kaldi-5.5.1112             |   cpu_hc0434e9_2        20.0 MB  conda-forge
#     kalpy-0.6.5                |cpu_py39h2ce7cd6_0         3.0 MB  conda-forge
#     keyutils-1.6.1             |       h166bdaf_0         115 KB  conda-forge
#     kiwisolver-1.4.5           |   py39h7633fee_1          72 KB  conda-forge
#     kneed-0.8.5                |     pyhd8ed1ab_0          15 KB  conda-forge
#     krb5-1.21.3                |       h659f571_0         1.3 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lazy-loader-0.4            |     pyhd8ed1ab_1          16 KB  conda-forge
#     lazy_loader-0.4            |     pyhd8ed1ab_1           6 KB  conda-forge
#     lcms2-2.16                 |       hb7c19ff_0         239 KB  conda-forge
#     ld_impl_linux-64-2.40      |       hf3520f5_7         691 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libabseil-20240116.2       | cxx17_he02047a_1         1.2 MB  conda-forge
#     libasprintf-0.22.5         |       he8f35ee_3          42 KB  conda-forge
#     libasprintf-devel-0.22.5   |       he8f35ee_3          33 KB  conda-forge
#     libass-0.17.3              |       h1dc1e6a_0         130 KB  conda-forge
#     libblas-3.9.0              |23_linux64_openblas          15 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hd590300_1          68 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd590300_1          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd590300_1         276 KB  conda-forge
#     libcblas-3.9.0             |23_linux64_openblas          14 KB  conda-forge
#     libdeflate-1.21            |       h4bc722e_0          69 KB  conda-forge
#     libdrm-2.4.123             |       hb9d3cd8_0         296 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libexpat-2.6.2             |       h59595ed_0          72 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libgcc-14.1.0              |       h77fa898_1         827 KB  conda-forge
#     libgcc-ng-14.1.0           |       h69a702a_1          51 KB  conda-forge
#     libgd-2.3.3                |      hd3e95f3_10         220 KB  conda-forge
#     libgettextpo-0.22.5        |       he02047a_3         167 KB  conda-forge
#     libgettextpo-devel-0.22.5  |       he02047a_3          36 KB  conda-forge
#     libgfortran-14.1.0         |       h69a702a_1          51 KB  conda-forge
#     libgfortran-ng-14.1.0      |       h69a702a_1          51 KB  conda-forge
#     libgfortran5-14.1.0        |       hc5f4f2c_1         1.4 MB  conda-forge
#     libglib-2.80.3             |       h315aac3_2         3.7 MB  conda-forge
#     libgomp-14.1.0             |       h77fa898_1         449 KB  conda-forge
#     libhwloc-2.11.1            |default_hecaa2ac_1000         2.3 MB  conda-forge
#     libiconv-1.17              |       hd590300_2         689 KB  conda-forge
#     libidn2-2.3.7              |       hd590300_0         124 KB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     liblapack-3.9.0            |23_linux64_openblas          14 KB  conda-forge
#     liblapacke-3.9.0           |23_linux64_openblas          14 KB  conda-forge
#     libllvm14-14.0.6           |       hcd5def8_4        30.0 MB  conda-forge
#     libnsl-2.0.1               |       hd590300_0          33 KB  conda-forge
#     libogg-1.3.5               |       h4ab18f5_0         201 KB  conda-forge
#     libopenblas-0.3.27         |pthreads_hac2b453_1         5.3 MB  conda-forge
#     libopenvino-2024.3.0       |       h2da1b83_0         5.1 MB  conda-forge
#     libopenvino-auto-batch-plugin-2024.3.0|       hb045406_0         108 KB  conda-forge
#     libopenvino-auto-plugin-2024.3.0|       hb045406_0         226 KB  conda-forge
#     libopenvino-hetero-plugin-2024.3.0|       h5c03a75_0         188 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2024.3.0|       h2da1b83_0        10.6 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2024.3.0|       h2da1b83_0         8.3 MB  conda-forge
#     libopenvino-intel-npu-plugin-2024.3.0|       h2da1b83_0         695 KB  conda-forge
#     libopenvino-ir-frontend-2024.3.0|       h5c03a75_0         197 KB  conda-forge
#     libopenvino-onnx-frontend-2024.3.0|       h07e8aee_0         1.5 MB  conda-forge
#     libopenvino-paddle-frontend-2024.3.0|       h07e8aee_0         667 KB  conda-forge
#     libopenvino-pytorch-frontend-2024.3.0|       he02047a_0         1.1 MB  conda-forge
#     libopenvino-tensorflow-frontend-2024.3.0|       h39126c6_0         1.2 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2024.3.0|       he02047a_0         460 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpciaccess-0.18          |       hd590300_0          28 KB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     libpq-16.4                 |       h482b261_0         2.4 MB  conda-forge
#     libprotobuf-4.25.3         |       h08a7969_0         2.7 MB  conda-forge
#     librosa-0.10.2.post1       |     pyhd8ed1ab_0         194 KB  conda-forge
#     librsvg-2.58.3             |       h9564881_0         6.0 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsqlite-3.46.0           |       hde9e2c9_0         845 KB  conda-forge
#     libstdcxx-14.1.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-ng-14.1.0        |       h4852527_1          51 KB  conda-forge
#     libtasn1-4.19.0            |       h166bdaf_0         114 KB  conda-forge
#     libtiff-4.6.0              |       h46a8edc_4         276 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     libuuid-2.38.1             |       h0b41bf4_0          33 KB  conda-forge
#     libva-2.22.0               |       hb711507_0         205 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.16                |       hb9d3cd8_1         386 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libxml2-2.12.7             |       he7c6b58_4         691 KB  conda-forge
#     libzlib-1.3.1              |       h4ab18f5_1          60 KB  conda-forge
#     llvmlite-0.43.0            |   py39h81bab63_0         3.2 MB  conda-forge
#     mad-0.15.1b                |       h9c3ff4c_1         113 KB  conda-forge
#     markdown-it-py-3.0.0       |     pyhd8ed1ab_0          63 KB  conda-forge
#     matplotlib-base-3.9.2      |   py39h0565ad7_0         6.6 MB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_0          14 KB  conda-forge
#     montreal-forced-aligner-3.1.3|     pyhd8ed1ab_1        11.0 MB  conda-forge
#     mpg123-1.32.6              |       h59595ed_0         480 KB  conda-forge
#     msgpack-python-1.0.8       |   py39h95fdab5_0          94 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     ncurses-6.5                |       he02047a_1         868 KB  conda-forge
#     nettle-3.9.1               |       h7ab15ed_0         988 KB  conda-forge
#     ngram-1.3.16               |       h434a139_1         2.0 MB  conda-forge
#     numba-0.60.0               |   py39h0320e7d_0         4.1 MB  conda-forge
#     numpy-1.26.4               |   py39h474f0d3_0         6.7 MB  conda-forge
#     ocl-icd-2.3.2              |       hd590300_1         133 KB  conda-forge
#     openfst-1.8.3              |       h00ab1b0_2         5.0 MB  conda-forge
#     openh264-2.4.1             |       h59595ed_0         718 KB  conda-forge
#     openjpeg-2.5.2             |       h488ebb8_0         334 KB  conda-forge
#     openssl-3.3.1              |       hb9d3cd8_3         2.8 MB  conda-forge
#     p11-kit-0.24.1             |       hc5aa10d_0         4.5 MB  conda-forge
#     packaging-24.1             |     pyhd8ed1ab_0          49 KB  conda-forge
#     pango-1.54.0               |       h4c5309f_1         437 KB  conda-forge
#     pcre2-10.44                |       hba22ea6_2         930 KB  conda-forge
#     pgvector-0.7.4             |       h2f8f9d6_0         112 KB  conda-forge
#     pgvector-python-0.3.2      |     pyhf9959ce_0          20 KB  conda-forge
#     pillow-10.4.0              |   py39h16a7006_0        40.1 MB  conda-forge
#     pip-24.2                   |     pyhd8ed1ab_0         1.2 MB  conda-forge
#     pixman-0.43.2              |       h59595ed_0         378 KB  conda-forge
#     platformdirs-4.2.2         |     pyhd8ed1ab_0          20 KB  conda-forge
#     pooch-1.8.2                |     pyhd8ed1ab_0          53 KB  conda-forge
#     postgresql-16.4            |       ha8faf9a_0         5.1 MB  conda-forge
#     praatio-6.0.0              |     pyhd8ed1ab_0          60 KB  conda-forge
#     psycopg2-2.9.9             |   py39h89197e3_0         169 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pugixml-1.14               |       h59595ed_0         112 KB  conda-forge
#     pycparser-2.22             |     pyhd8ed1ab_0         103 KB  conda-forge
#     pygments-2.18.0            |     pyhd8ed1ab_0         859 KB  conda-forge
#     pynini-2.1.6               |   py39h7633fee_0         1.6 MB  conda-forge
#     pyparsing-3.1.4            |     pyhd8ed1ab_0          88 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     pysoundfile-0.12.1         |   pypyhd8ed1ab_1          28 KB  conda-forge
#     python-3.9.19              |h0755675_0_cpython        22.7 MB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python_abi-3.9             |           5_cp39           6 KB  conda-forge
#     pyyaml-6.0.2               |   py39hcd6043d_0         177 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     readline-8.2               |       h8228510_1         275 KB  conda-forge
#     requests-2.32.3            |     pyhd8ed1ab_0          57 KB  conda-forge
#     rich-13.7.1                |     pyhd8ed1ab_0         180 KB  conda-forge
#     rich-click-1.8.3           |     pyhd8ed1ab_0          33 KB  conda-forge
#     scikit-learn-1.2.2         |   py39hc236052_2         7.3 MB  conda-forge
#     scipy-1.13.1               |   py39haf93ffa_0        15.8 MB  conda-forge
#     setuptools-72.2.0          |     pyhd8ed1ab_0         1.4 MB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     snappy-1.2.1               |       ha2e4443_0          41 KB  conda-forge
#     sox-14.4.2                 |    h32e7c5b_1019         503 KB  conda-forge
#     soxr-0.1.3                 |       h0b41bf4_3         128 KB  conda-forge
#     soxr-python-0.4.0          |   py39h988be6c_0         269 KB  conda-forge
#     sqlalchemy-2.0.32          |   py39hcd6043d_0         2.7 MB  conda-forge
#     sqlite-3.46.0              |       h6d4b2fc_0         840 KB  conda-forge
#     svt-av1-2.2.1              |       h5888daf_0         2.3 MB  conda-forge
#     tbb-2021.12.0              |       h84d6215_4         183 KB  conda-forge
#     threadpoolctl-3.5.0        |     pyhc1e730c_0          23 KB  conda-forge
#     tk-8.6.13                  |noxft_h4845f30_101         3.2 MB  conda-forge
#     tqdm-4.66.5                |     pyhd8ed1ab_0          87 KB  conda-forge
#     typing-extensions-4.12.2   |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.12.2   |     pyha770c72_0          39 KB  conda-forge
#     tzcode-2024a               |       h3f72095_0          68 KB  conda-forge
#     tzdata-2024a               |       h8827d51_1         121 KB  conda-forge
#     unicodedata2-15.1.0        |   py39hd1e30aa_0         365 KB  conda-forge
#     urllib3-2.2.2              |     pyhd8ed1ab_1          93 KB  conda-forge
#     wayland-1.23.1             |       h3e06ad9_0         314 KB  conda-forge
#     wayland-protocols-1.36     |       hd8ed1ab_0          89 KB  conda-forge
#     wheel-0.44.0               |     pyhd8ed1ab_0          57 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.1.1          |       hd590300_0          57 KB  conda-forge
#     xorg-libsm-1.2.4           |       h7391055_0          27 KB  conda-forge
#     xorg-libx11-1.8.9          |       hb711507_1         813 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-libxrender-0.9.11     |       hd590300_0          37 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h0b41bf4_1003          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zipp-3.20.1                |     pyhd8ed1ab_0          21 KB  conda-forge
#     zlib-1.3.1                 |       h4ab18f5_1          91 KB  conda-forge
#     zstandard-0.23.0           |   py39h623c9ba_0         396 KB  conda-forge
#     zstd-1.5.6                 |       ha6fb4c9_0         542 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       348.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.38.0-h04ea711_2
#   audioread          conda-forge/linux-64::audioread-3.0.1-py39hf3d152e_1
#   baumwelch          conda-forge/linux-64::baumwelch-0.3.9-h434a139_3
#   biopython          conda-forge/linux-64::biopython-1.79-py39hb9d737c_3
#   brotli             conda-forge/linux-64::brotli-1.1.0-hd590300_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hd590300_1
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py39h3d6467e_1
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.7.4-hbcca054_0
#   cairo              conda-forge/linux-64::cairo-1.18.0-hebfffa5_3
#   certifi            conda-forge/noarch::certifi-2024.7.4-pyhd8ed1ab_0
#   cffi               conda-forge/linux-64::cffi-1.17.0-py39h49a4b6b_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.3.2-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/linux-64::contourpy-1.2.1-py39h7633fee_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dataclassy         conda-forge/noarch::dataclassy-1.0.1-pyhd8ed1ab_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   decorator          conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0
#   expat              conda-forge/linux-64::expat-2.6.2-h59595ed_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.0.2-gpl_h226ea3b_102
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_2
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.53.1-py39hcd6043d_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   gettext            conda-forge/linux-64::gettext-0.22.5-he02047a_3
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.22.5-he02047a_3
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   gnutls             conda-forge/linux-64::gnutls-3.8.7-h32866dd_0
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   graphviz           conda-forge/linux-64::graphviz-12.0.0-hba01fac_0
#   greenlet           conda-forge/linux-64::greenlet-3.0.3-py39h3d6467e_0
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-h6470451_5
#   gts                conda-forge/linux-64::gts-0.7.6-h977cf35_4
#   h2                 conda-forge/noarch::h2-4.1.0-pyhd8ed1ab_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-9.0.0-hda332d3_1
#   hdbscan            conda-forge/linux-64::hdbscan-0.8.38.post1-py39h988be6c_1
#   hpack              conda-forge/noarch::hpack-4.0.0-pyh9f0ad1d_0
#   hyperframe         conda-forge/noarch::hyperframe-6.0.1-pyhd8ed1ab_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   idna               conda-forge/noarch::idna-3.8-pyhd8ed1ab_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.4.0-pyha770c72_0
#   importlib-resourc~ conda-forge/noarch::importlib-resources-6.4.4-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.4-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.4.2-pyhd8ed1ab_0
#   kaldi              conda-forge/linux-64::kaldi-5.5.1112-cpu_hc0434e9_2
#   kalpy              conda-forge/linux-64::kalpy-0.6.5-cpu_py39h2ce7cd6_0
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.5-py39h7633fee_1
#   kneed              conda-forge/noarch::kneed-0.8.5-pyhd8ed1ab_0
#   krb5               conda-forge/linux-64::krb5-1.21.3-h659f571_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lazy-loader        conda-forge/noarch::lazy-loader-0.4-pyhd8ed1ab_1
#   lazy_loader        conda-forge/noarch::lazy_loader-0.4-pyhd8ed1ab_1
#   lcms2              conda-forge/linux-64::lcms2-2.16-hb7c19ff_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-hf3520f5_7
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libabseil          conda-forge/linux-64::libabseil-20240116.2-cxx17_he02047a_1
#   libasprintf        conda-forge/linux-64::libasprintf-0.22.5-he8f35ee_3
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.22.5-he8f35ee_3
#   libass             conda-forge/linux-64::libass-0.17.3-h1dc1e6a_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-23_linux64_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hd590300_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hd590300_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hd590300_1
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-23_linux64_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.21-h4bc722e_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.123-hb9d3cd8_0
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libexpat           conda-forge/linux-64::libexpat-2.6.2-h59595ed_0
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libgcc             conda-forge/linux-64::libgcc-14.1.0-h77fa898_1
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.1.0-h69a702a_1
#   libgd              conda-forge/linux-64::libgd-2.3.3-hd3e95f3_10
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.22.5-he02047a_3
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.22.5-he02047a_3
#   libgfortran        conda-forge/linux-64::libgfortran-14.1.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.1.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.1.0-hc5f4f2c_1
#   libglib            conda-forge/linux-64::libglib-2.80.3-h315aac3_2
#   libgomp            conda-forge/linux-64::libgomp-14.1.0-h77fa898_1
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.1-default_hecaa2ac_1000
#   libiconv           conda-forge/linux-64::libiconv-1.17-hd590300_2
#   libidn2            conda-forge/linux-64::libidn2-2.3.7-hd590300_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-23_linux64_openblas
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-23_linux64_openblas
#   libllvm14          conda-forge/linux-64::libllvm14-14.0.6-hcd5def8_4
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-h4ab18f5_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.27-pthreads_hac2b453_1
#   libopenvino        conda-forge/linux-64::libopenvino-2024.3.0-h2da1b83_0
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2024.3.0-hb045406_0
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2024.3.0-hb045406_0
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2024.3.0-h5c03a75_0
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2024.3.0-h2da1b83_0
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2024.3.0-h2da1b83_0
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2024.3.0-h2da1b83_0
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2024.3.0-h5c03a75_0
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2024.3.0-h07e8aee_0
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2024.3.0-h07e8aee_0
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2024.3.0-he02047a_0
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2024.3.0-h39126c6_0
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2024.3.0-he02047a_0
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hd590300_0
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libpq              conda-forge/linux-64::libpq-16.4-h482b261_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-4.25.3-h08a7969_0
#   librosa            conda-forge/noarch::librosa-0.10.2.post1-pyhd8ed1ab_0
#   librsvg            conda-forge/linux-64::librsvg-2.58.3-h9564881_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.46.0-hde9e2c9_0
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.1.0-hc0a3c3a_1
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.1.0-h4852527_1
#   libtasn1           conda-forge/linux-64::libtasn1-4.19.0-h166bdaf_0
#   libtiff            conda-forge/linux-64::libtiff-4.6.0-h46a8edc_4
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libva              conda-forge/linux-64::libva-2.22.0-hb711507_0
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.16-hb9d3cd8_1
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libxml2            conda-forge/linux-64::libxml2-2.12.7-he7c6b58_4
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-h4ab18f5_1
#   llvmlite           conda-forge/linux-64::llvmlite-0.43.0-py39h81bab63_0
#   mad                conda-forge/linux-64::mad-0.15.1b-h9c3ff4c_1
#   markdown-it-py     conda-forge/noarch::markdown-it-py-3.0.0-pyhd8ed1ab_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.9.2-py39h0565ad7_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_0
#   montreal-forced-a~ conda-forge/noarch::montreal-forced-aligner-3.1.3-pyhd8ed1ab_1
#   mpg123             conda-forge/linux-64::mpg123-1.32.6-h59595ed_0
#   msgpack-python     conda-forge/linux-64::msgpack-python-1.0.8-py39h95fdab5_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   ncurses            conda-forge/linux-64::ncurses-6.5-he02047a_1
#   nettle             conda-forge/linux-64::nettle-3.9.1-h7ab15ed_0
#   ngram              conda-forge/linux-64::ngram-1.3.16-h434a139_1
#   numba              conda-forge/linux-64::numba-0.60.0-py39h0320e7d_0
#   numpy              conda-forge/linux-64::numpy-1.26.4-py39h474f0d3_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.2-hd590300_1
#   openfst            conda-forge/linux-64::openfst-1.8.3-h00ab1b0_2
#   openh264           conda-forge/linux-64::openh264-2.4.1-h59595ed_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.2-h488ebb8_0
#   openssl            conda-forge/linux-64::openssl-3.3.1-hb9d3cd8_3
#   p11-kit            conda-forge/linux-64::p11-kit-0.24.1-hc5aa10d_0
#   packaging          conda-forge/noarch::packaging-24.1-pyhd8ed1ab_0
#   pango              conda-forge/linux-64::pango-1.54.0-h4c5309f_1
#   pcre2              conda-forge/linux-64::pcre2-10.44-hba22ea6_2
#   pgvector           conda-forge/linux-64::pgvector-0.7.4-h2f8f9d6_0
#   pgvector-python    conda-forge/noarch::pgvector-python-0.3.2-pyhf9959ce_0
#   pillow             conda-forge/linux-64::pillow-10.4.0-py39h16a7006_0
#   pip                conda-forge/noarch::pip-24.2-pyhd8ed1ab_0
#   pixman             conda-forge/linux-64::pixman-0.43.2-h59595ed_0
#   platformdirs       conda-forge/noarch::platformdirs-4.2.2-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.8.2-pyhd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-16.4-ha8faf9a_0
#   praatio            conda-forge/noarch::praatio-6.0.0-pyhd8ed1ab_0
#   psycopg2           conda-forge/linux-64::psycopg2-2.9.9-py39h89197e3_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pugixml            conda-forge/linux-64::pugixml-1.14-h59595ed_0
#   pycparser          conda-forge/noarch::pycparser-2.22-pyhd8ed1ab_0
#   pygments           conda-forge/noarch::pygments-2.18.0-pyhd8ed1ab_0
#   pynini             conda-forge/linux-64::pynini-2.1.6-py39h7633fee_0
#   pyparsing          conda-forge/noarch::pyparsing-3.1.4-pyhd8ed1ab_0
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   pysoundfile        conda-forge/noarch::pysoundfile-0.12.1-pypyhd8ed1ab_1
#   python             conda-forge/linux-64::python-3.9.19-h0755675_0_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0-pyhd8ed1ab_0
#   python_abi         conda-forge/linux-64::python_abi-3.9-5_cp39
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py39hcd6043d_0
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   requests           conda-forge/noarch::requests-2.32.3-pyhd8ed1ab_0
#   rich               conda-forge/noarch::rich-13.7.1-pyhd8ed1ab_0
#   rich-click         conda-forge/noarch::rich-click-1.8.3-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.2.2-py39hc236052_2
#   scipy              conda-forge/linux-64::scipy-1.13.1-py39haf93ffa_0
#   setuptools         conda-forge/noarch::setuptools-72.2.0-pyhd8ed1ab_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   snappy             conda-forge/linux-64::snappy-1.2.1-ha2e4443_0
#   sox                conda-forge/linux-64::sox-14.4.2-h32e7c5b_1019
#   soxr               conda-forge/linux-64::soxr-0.1.3-h0b41bf4_3
#   soxr-python        conda-forge/linux-64::soxr-python-0.4.0-py39h988be6c_0
#   sqlalchemy         conda-forge/linux-64::sqlalchemy-2.0.32-py39hcd6043d_0
#   sqlite             conda-forge/linux-64::sqlite-3.46.0-h6d4b2fc_0
#   svt-av1            conda-forge/linux-64::svt-av1-2.2.1-h5888daf_0
#   tbb                conda-forge/linux-64::tbb-2021.12.0-h84d6215_4
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.5.0-pyhc1e730c_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tqdm               conda-forge/noarch::tqdm-4.66.5-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.12.2-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.12.2-pyha770c72_0
#   tzcode             conda-forge/linux-64::tzcode-2024a-h3f72095_0
#   tzdata             conda-forge/noarch::tzdata-2024a-h8827d51_1
#   unicodedata2       conda-forge/linux-64::unicodedata2-15.1.0-py39hd1e30aa_0
#   urllib3            conda-forge/noarch::urllib3-2.2.2-pyhd8ed1ab_1
#   wayland            conda-forge/linux-64::wayland-1.23.1-h3e06ad9_0
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.36-hd8ed1ab_0
#   wheel              conda-forge/noarch::wheel-0.44.0-pyhd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.9-hb711507_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.11-hd590300_0
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zipp               conda-forge/noarch::zipp-3.20.1-pyhd8ed1ab_0
#   zlib               conda-forge/linux-64::zlib-1.3.1-h4ab18f5_1
#   zstandard          conda-forge/linux-64::zstandard-0.23.0-py39h623c9ba_0
#   zstd               conda-forge/linux-64::zstd-1.5.6-ha6fb4c9_0
#
#
#
# Downloading and Extracting Packages:
# pillow-10.4.0        | 40.1 MB   |                                       |   0%
# libllvm14-14.0.6     | 30.0 MB   |                                       |   0%
#
# python-3.9.19        | 22.7 MB   |                                       |   0%
#
#
# kaldi-5.5.1112       | 20.0 MB   |                                       |   0%
#
#
#
# scipy-1.13.1         | 15.8 MB   |                                       |   0%
#
#
#
#
# icu-75.1             | 11.6 MB   |                                       |   0%
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   |                                       |   0%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   |                                       |   0%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# scikit-learn-1.2.2   | 7.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.3       | 6.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-16.4      | 5.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.3.0 | 5.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openfst-1.8.3        | 5.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.60.0         | 4.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.3       | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.1.0     | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-10.4.0        | 40.1 MB   | 3                                     |   1%
# libllvm14-14.0.6     | 30.0 MB   | 2                                     |   1%
#
#
#
# scipy-1.13.1         | 15.8 MB   | 7                                     |   2%
#
#
# kaldi-5.5.1112       | 20.0 MB   | 2                                     |   1%
#
# python-3.9.19        | 22.7 MB   | ###6                                  |  10%
# libllvm14-14.0.6     | 30.0 MB   | ##1                                   |   6%
#
#
#
# scipy-1.13.1         | 15.8 MB   | ######                                |  16%
#
#
# pillow-10.4.0        | 40.1 MB   | ##                                    |   6%
#
# python-3.9.19        | 22.7 MB   | #######5                              |  20%
# libllvm14-14.0.6     | 30.0 MB   | ####9                                 |  13%
#
#
#
# scipy-1.13.1         | 15.8 MB   | #########7                            |  26%
#
#
# pillow-10.4.0        | 40.1 MB   | ###8                                  |  11%
#
# python-3.9.19        | 22.7 MB   | ##########7                           |  29%
#
#
#
# scipy-1.13.1         | 15.8 MB   | #############9                        |  38%
# libllvm14-14.0.6     | 30.0 MB   | #######8                              |  21%
#
#
# pillow-10.4.0        | 40.1 MB   | #####9                                |  16%
# libllvm14-14.0.6     | 30.0 MB   | ##########4                           |  28%
#
# python-3.9.19        | 22.7 MB   | #############7                        |  37%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ######8                               |  19%
#
#
#
# pillow-10.4.0        | 40.1 MB   | #######5                              |  20%
# libllvm14-14.0.6     | 30.0 MB   | ############7                         |  35%
#
# python-3.9.19        | 22.7 MB   | ################6                     |  45%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ########5                             |  23%
#
#
#
# pillow-10.4.0        | 40.1 MB   | #########1                            |  25%
# libllvm14-14.0.6     | 30.0 MB   | ###############3                      |  41%
#
# python-3.9.19        | 22.7 MB   | ###################6                  |  53%
#
#
#
# scipy-1.13.1         | 15.8 MB   | #########################6            |  69%
#
#
# pillow-10.4.0        | 40.1 MB   | ##########7                           |  29%
#
# python-3.9.19        | 22.7 MB   | ######################4               |  61%
# libllvm14-14.0.6     | 30.0 MB   | #################7                    |  48%
#
#
#
# scipy-1.13.1         | 15.8 MB   | #############################3        |  79%
#
#
# pillow-10.4.0        | 40.1 MB   | ############2                         |  33%
# libllvm14-14.0.6     | 30.0 MB   | ####################                  |  54%
#
# python-3.9.19        | 22.7 MB   | #########################2            |  68%
#
#
#
# scipy-1.13.1         | 15.8 MB   | #################################6    |  91%
#
#
# pillow-10.4.0        | 40.1 MB   | #############6                        |  37%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ###############1                      |  41%
# libllvm14-14.0.6     | 30.0 MB   | ######################2               |  60%
#
# python-3.9.19        | 22.7 MB   | ###########################8          |  75%
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##############9                       |  40%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ################7                     |  45%
# libllvm14-14.0.6     | 30.0 MB   | ########################2             |  66%
#
#
#
#
# icu-75.1             | 11.6 MB   | ####9                                 |  13%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ##################3                   |  49%
#
# pillow-10.4.0        | 40.1 MB   | ################1                     |  44%
#
#
#
# scipy-1.13.1         | 15.8 MB   | ##################################### | 100%
# libllvm14-14.0.6     | 30.0 MB   | ##########################2           |  71%
#
#
#
#
# icu-75.1             | 11.6 MB   | ##########1                           |  27%
#
#
# pillow-10.4.0        | 40.1 MB   | #################2                    |  47%
#
# python-3.9.19        | 22.7 MB   | ################################1     |  87%
#
#
#
#
# icu-75.1             | 11.6 MB   | ###############3                      |  41%
# libllvm14-14.0.6     | 30.0 MB   | ############################          |  76%
#
#
# kaldi-5.5.1112       | 20.0 MB   | #####################2                |  58%
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##################1                   |  49%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ######################7               |  62%
#
# python-3.9.19        | 22.7 MB   | #################################9    |  92%
# libllvm14-14.0.6     | 30.0 MB   | #############################6        |  80%
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ###################1                  |  52%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ########################4             |  66%
# libllvm14-14.0.6     | 30.0 MB   | ###############################1      |  84%
#
#
#
#
# icu-75.1             | 11.6 MB   | #############################8        |  81%
#
# python-3.9.19        | 22.7 MB   | ###################################4  |  96%
#
#
# pillow-10.4.0        | 40.1 MB   | ###################9                  |  54%
#
#
#
#
# icu-75.1             | 11.6 MB   | ##################################6   |  94%
# libllvm14-14.0.6     | 30.0 MB   | ################################5     |  88%
#
#
# pillow-10.4.0        | 40.1 MB   | ####################8                 |  56%
#
# python-3.9.19        | 22.7 MB   | ####################################8 |  99%
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   |                                       |   0%
# libllvm14-14.0.6     | 30.0 MB   | #################################7    |  91%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ############################7         |  78%
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | #####################5                |  58%
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | ####2                                 |  11%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   |                                       |   0%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ##############################2       |  82%
# pillow-10.4.0        | 40.1 MB   | ######################2               |  60%
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | ###########2                          |  30%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | ##                                    |   6%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ################################6     |  88%
# pillow-10.4.0        | 40.1 MB   | #######################4              |  63%
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | #####################4                |  58%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | #####8                                |  16%
#
#
# pillow-10.4.0        | 40.1 MB   | #########################1            |  68%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    |                                       |   0%
#
# python-3.9.19        | 22.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    |                                       |   0%
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | ###################################9  |  97%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ###########################           |  73%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
# scikit-learn-1.2.2   | 7.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    | ########7                             |  24%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | #############9                        |  38%
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ############################4         |  77%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | ########8                             |  24%
#
#
#
#
#
#
#
#
#
# scikit-learn-1.2.2   | 7.3 MB    | ############4                         |  34%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    | ###################5                  |  53%
# libllvm14-14.0.6     | 30.0 MB   | ##################################### | 100%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | #############5                        |  36%
#
#
#
#
#
#
#
#
#
# scikit-learn-1.2.2   | 7.3 MB    | ########################8             |  67%
#
#
# kaldi-5.5.1112       | 20.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    | ############################9         |  78%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ################################6     |  88%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
# scikit-learn-1.2.2   | 7.3 MB    | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    |                                       |   0%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | ############################8         |  78%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    | ##########2                           |  28%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | #################################2    |  90%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.3       | 6.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# scikit-learn-1.2.2   | 7.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-16.4      | 5.1 MB    | 1                                     |   0%
#
#
#
#
#
#
#
# ffmpeg-7.0.2         | 9.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.3       | 6.0 MB    | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ####################7                 |  56%
#
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.3.0 | 5.1 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-16.4      | 5.1 MB    | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.3       | 6.0 MB    | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.3.0 | 5.1 MB    | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openfst-1.8.3        | 5.0 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.3       | 6.0 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.3       | 3.7 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.60.0         | 4.1 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openfst-1.8.3        | 5.0 MB    | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.1.0     | 3.7 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.60.0         | 4.1 MB    | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.1.0     | 3.7 MB    | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.60.0         | 4.1 MB    | ################################7     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-16.4      | 5.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-16.4      | 5.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 6.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.3       | 6.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.3.0 | 5.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.3.0 | 5.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.1.0     | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openfst-1.8.3        | 5.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.3       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.80.3       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.60.0         | 4.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: /
# \
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate aligner
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# For the following command, if you failed running in the jupyter notebook (e.g. with `CondaError: Run 'conda init' before 'conda activate'`), please run it in the terminal by yourself.

# %%
# activate conda environment
# !conda activate aligner

# download pre-trained MFA models
# !mfa model download g2p english_us_arpa
# !mfa model download acoustic english_us_arpa
# !mfa model download dictionary english_us_arpa
# !conda deactivate
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
# /bin/bash: line 1: mfa: command not found
# /bin/bash: line 1: mfa: command not found
# /bin/bash: line 1: mfa: command not found
# CondaError: Run 'conda init' before 'conda deactivate'

# %% [markdown]
# Note: we use "aligner" as the environment name throughout the Voicebox project. Please don't use your customized name at this point, unless you know how to fix the code accordingly.

# %% [markdown]
# ## Other Requirements

# %%
# !./scripts/installers/install_torchaudio_latest.sh
# !pip install textgrid descript-audio-codec openai-whisper s3prl torchode encodec vocos resemblyzer lhotse==1.26.0
# !pip install -U jiwer onnx wandb tensorboard
# !pip install bitarray git+https://github.com/facebookresearch/fairseq.git#fairseq --no-deps

# %% [markdown]
# # Preprocess LibriLight w/ LibriHeavy
# - LibriLight is an audio dataset consists of audiobooks.
# - LibriHeavy is a transcripted version of LibriLight, which is a manifest consists of LibriLight's utterances' transcripts.
# - In this section, we need to cut the audiobook chapter audios into utterances according to LibriHeavy's provided transcripts, such that MFA can align each utterance with its transcript.

# %%
import os
import logging
from functools import partial
import lhotse
from lhotse.recipes.utils import manifests_exist
from lhotse.cut import CutSet, Cut
from lhotse.serialization import load_manifest_lazy_or_eager, load_manifest

from scripts.dataset_processing.tts.libriheavy.mfa_prepare import get_subset_audio, change_prefix, save_texts_and_audios

old_prefix = "download/librilight"  # prefix to replace in libriheavy manifest
librilight_dir = "data/download/LibriLight" # directory with librilight audio data
libriheavy_dir = "data/download/LibriHeavy" # directory with libriheavy manifest data
audio_cuts_dir = "data/aligned/LibriHeavy/raw_data_cuts" # directory to save processed audio data

# %% [markdown]
# ## Download LibriLight
# LibriHeavy repo: https://github.com/k2-fsa/libriheavy/tree/master

# %%
# download librilight

dataset_parts = ["small", "medium", "large"]
target_dir = librilight_dir

print("Stage -1: Downloading audio file.")

os.makedirs(target_dir, exist_ok=True)
for subset in dataset_parts:
    logging.info("Downloading ${subset} subset.")
    if not os.path.exists(f"{target_dir}/{subset}"):
        os.system(f"wget -P {target_dir} -c https://dl.fbaipublicfiles.com/librilight/data/{subset}.tar")
        os.system(f"tar xf {target_dir}/{subset}.tar -C {target_dir}")
    else:
        print(f"Skipping download, {subset} subset exists.")
# Out:
# Stage -1: Downloading audio file.
# Skipping download, small subset exists.
# Skipping download, medium subset exists.
# Skipping download, large subset exists.

# %%
# download libriheavy manifests

dataset_parts = ["small", "medium", "large", "dev", "test_clean", "test_other", "test_clean_large", "test_other_large"]
target_dir = libriheavy_dir

print(f"mkdir -p {target_dir}")
os.makedirs(target_dir, exist_ok=True)
for subset in dataset_parts:
    if not manifests_exist(subset, target_dir, ["cuts"], "libriheavy"):
        print(f"Downloading {subset} subset.")
        os.system(f"wget -P {target_dir} -c https://huggingface.co/datasets/pkufool/libriheavy/resolve/main/libriheavy_cuts_{subset}.jsonl.gz")
    else:
        print(f"Skipping download, {subset} subset exists.")
# Out:
# mkdir -p data/download/LibriHeavy
# Skipping download, small subset exists.
# Skipping download, medium subset exists.
# Skipping download, large subset exists.
# Skipping download, dev subset exists.
# Skipping download, test_clean subset exists.
# Skipping download, test_other subset exists.
# Skipping download, test_clean_large subset exists.
# Skipping download, test_other_large subset exists.

# %%
# process libriheavy manifests for MFA

subsets = ["small", "dev", "test_clean", "test_other"]
# subsets = ["medium"]
# subsets = ["large", "test_clean_large", "tesst_other_large"]

for subset in subsets:
    # can not lazily split with progress bar
    cuts: CutSet = load_manifest_lazy_or_eager(f"{libriheavy_dir}/libriheavy_cuts_{subset}.jsonl.gz", CutSet)
    cuts = cuts.filter(lambda c: ',' not in c.id)
    cuts = cuts.map(partial(change_prefix, old_prefix=old_prefix, new_prefix=librilight_dir))

    storage_path=f"{audio_cuts_dir}/{subset}"
    cuts = cuts.to_eager()
    save_texts_and_audios(cuts=cuts, storage_path=storage_path, num_jobs=32)
# Out:
# Storing audio and transcripts: 100%|██████████| 3829/3829 [00:00<00:00, 7394.60it/s]
# Storing audio and transcripts (chunks progress): 100%|██████████| 32/32 [00:09<00:00,  3.37it/s]
# Storing audio and transcripts: 100%|██████████| 168/168 [00:03<00:00, 44.63it/s]
# Storing audio and transcripts (chunks progress): 100%|██████████| 32/32 [00:05<00:00,  5.86it/s]
# Storing audio and transcripts: 100%|██████████| 80/80 [00:01<00:00, 69.61it/s]
# Storing audio and transcripts (chunks progress): 100%|██████████| 32/32 [00:03<00:00,  9.61it/s]
# Storing audio and transcripts: 100%|██████████| 88/88 [00:01<00:00, 65.43it/s]
# Storing audio and transcripts (chunks progress): 100%|██████████| 32/32 [00:02<00:00, 10.83it/s]

# %% [markdown]
# ### (Optional) get eval data only
# If your environment does not allow

# %% [markdown]
# # Preprocess GigaSpeech

# %%
! pip install datasets
import os
import datasets
from datasets import load_dataset
from tqdm import tqdm
import soundfile as sf

subsets = ["xs", "s", "m", "l", "xl"]

def has_valid_audio(ex):
    try:
        sf.read(ex["audio"]["path"])
    except Exception:
        print(ex["audio"]["path"])
        return False
    return True

for subset in tqdm(subsets, desc="subset"):
    ds = load_dataset(
        "esb/datasets", "gigaspeech", subconfig=subset,
        download_config=datasets.DownloadConfig(resume_download=True),
        num_proc=8,
    )
    print(ds)
    ds = ds.cast_column("audio", datasets.Audio(decode=False))
    ds = ds.filter(has_valid_audio)
    ds = ds.cast_column("audio", datasets.Audio(decode=True))
    print(ds)
    for data in ds["train"]:
        pass
